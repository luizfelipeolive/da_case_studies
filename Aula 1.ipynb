# %%
preco = 100

# %%
print (preco)

# %% [markdown]
# # Python para Análise de Dados
#
# ## Introdução ao ambiente de trabalho
#
# Prof. Luiz Felipe Oliveira Barroso

# %% [markdown]
# ## Objetivos da aula
#
# Ao final desta aula, o estudante deverá ser capaz de:
#
# - compreender o papel do Python;
# - diferenciar Python, IPython e Jupyter;
# - executar códigos em notebooks.

# %% [markdown]
# ## Primeiro exemplo
#
# Vamos calcular a média de alguns preços.

# %%
precos = [10, 15, 20, 25]

media = sum(precos) / len(precos)

media
# Out:
# 17.5

# %% [markdown]
# <!-- slide -->
#
# # Análise de vendas de uma cafeteria
#
# ## Teste de apresentação com Jupyter Notebook
#
# Exemplo com:
#
# - tabelas;
# - fórmulas em LaTeX;
# - código Python;
# - gráficos;
# - diferentes tipos de slides.
#
# Essa célula será a capa da apresentação.

# %% [markdown]
# <!-- slide -->
#
# ## Objetivos do exemplo
#
# Ao final desta apresentação, queremos testar:
#
# - a criação de slides horizontais;
# - a criação de subslides verticais;
# - o aparecimento progressivo de conteúdo;
# - a exibição de tabelas;
# - a renderização de equações;
# - a inclusão de código e resultados.
#
# Essa célula começa um novo slide horizontal.
